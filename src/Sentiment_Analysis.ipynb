# %% [markdown]
# # Load Packages

# %%
import nltk
import os
from os import path, getcwd
import random
import numpy as np
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import re
import gc; gc.enable()
sns.set()
pd.set_option("display.max_columns",None)

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/rileyjefferson/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# # Load
# - Analyze english tweets with Vader Sentiment Analysis

# %%
df = pd.read_csv('../fw_full.csv',low_memory=False)

# %%
df = df[df['lang']=='en']
df.reset_index(drop=True,inplace=True)

# %%
df.head(3)
# Out:
#       user_id             status_id        created_at created_at.1  \
# 0  x538238041  x1130947670040883200  2019-05-21 21:25   9:25:00 PM
# 1  x538238041  x1130578559242821632  2019-05-20 20:58   8:58:00 PM
# 2  x538238041  x1130578318422663169  2019-05-20 20:57   8:57:00 PM
#
#       screen_name                                               text  \
# 0  7KingdomsRMine         @ellariasnake *swoops in and hugs forever*
# 1  7KingdomsRMine    @danygonebad @MaekarTarg *brings the gin tonic*
# 2  7KingdomsRMine  @Sunspear_Snake A mere spot of bother for my n...
#
#                 source  display_text_width    reply_to_status_id  \
# 0  Twitter for Android                  28  x1130947259846127616
# 1  Twitter for Android                  22  x1130577205225033733
# 2  Twitter for Android                  36  x1130573147420254208
#
#       reply_to_user_id reply_to_screen_name  is_quote  is_retweet  \
# 0          x2466814554         ellariasnake     False       False
# 1           x607150882          danygonebad     False       False
# 2  x750065186380406785       Sunspear_Snake     False       False
#
#    favorite_count  retweet_count hashtags  symbols urls_url urls_t.co  \
# 0               1              0      NaN      NaN      NaN       NaN
# 1               1              0      NaN      NaN      NaN       NaN
# 2               0              0      NaN      NaN      NaN       NaN
#
#   urls_expanded_url media_url media_t.co media_expanded_url media_type  \
# 0               NaN       NaN        NaN                NaN        NaN
# 1               NaN       NaN        NaN                NaN        NaN
# 2               NaN       NaN        NaN                NaN        NaN
#
#   ext_media_url ext_media_t.co ext_media_expanded_url  ext_media_type  \
# 0           NaN            NaN                    NaN             NaN
# 1           NaN            NaN                    NaN             NaN
# 2           NaN            NaN                    NaN             NaN
#
#                  mentions_user_id    mentions_screen_name lang  \
# 0                     x2466814554            ellariasnake   en
# 1  x607150882 x890587538473267200  danygonebad MaekarTarg   en
# 2             x750065186380406785          Sunspear_Snake   en
#
#   quoted_status_id quoted_text quoted_created_at quoted_source  \
# 0              NaN         NaN               NaN           NaN
# 1              NaN         NaN               NaN           NaN
# 2              NaN         NaN               NaN           NaN
#
#    quoted_favorite_count  quoted_retweet_count quoted_user_id  \
# 0                    NaN                   NaN            NaN
# 1                    NaN                   NaN            NaN
# 2                    NaN                   NaN            NaN
#
#   quoted_screen_name quoted_name  quoted_followers_count  \
# 0                NaN         NaN                     NaN
# 1                NaN         NaN                     NaN
# 2                NaN         NaN                     NaN
#
#    quoted_friends_count  quoted_statuses_count quoted_location  \
# 0                   NaN                    NaN             NaN
# 1                   NaN                    NaN             NaN
# 2                   NaN                    NaN             NaN
#
#   quoted_description quoted_verified retweet_status_id retweet_text  \
# 0                NaN             NaN               NaN          NaN
# 1                NaN             NaN               NaN          NaN
# 2                NaN             NaN               NaN          NaN
#
#   retweet_created_at retweet_source  retweet_favorite_count  \
# 0                NaN            NaN                     NaN
# 1                NaN            NaN                     NaN
# 2                NaN            NaN                     NaN
#
#    retweet_retweet_count retweet_user_id retweet_screen_name retweet_name  \
# 0                    NaN             NaN                 NaN          NaN
# 1                    NaN             NaN                 NaN          NaN
# 2                    NaN             NaN                 NaN          NaN
#
#    retweet_followers_count  retweet_friends_count  retweet_statuses_count  \
# 0                      NaN                    NaN                     NaN
# 1                      NaN                    NaN                     NaN
# 2                      NaN                    NaN                     NaN
#
#   retweet_location retweet_description retweet_verified  place_url  \
# 0              NaN                 NaN              NaN        NaN
# 1              NaN                 NaN              NaN        NaN
# 2              NaN                 NaN              NaN        NaN
#
#    place_name  place_full_name  place_type  country  country_code geo_coords  \
# 0         NaN              NaN         NaN      NaN           NaN      NA NA
# 1         NaN              NaN         NaN      NaN           NaN      NA NA
# 2         NaN              NaN         NaN      NaN           NaN      NA NA
#
#   coords_coords              bbox_coords  \
# 0         NA NA  NA NA NA NA NA NA NA NA
# 1         NA NA  NA NA NA NA NA NA NA NA
# 2         NA NA  NA NA NA NA NA NA NA NA
#
#                                           status_url  \
# 0  https://twitter.com/7KingdomsRMine/status/1130...
# 1  https://twitter.com/7KingdomsRMine/status/1130...
# 2  https://twitter.com/7KingdomsRMine/status/1130...
#
#                                 name         location  \
# 0  Vissie III of the House Targaryen  The seven hells
# 1  Vissie III of the House Targaryen  The seven hells
# 2  Vissie III of the House Targaryen  The seven hells
#
#                                          description                      url  \
# 0  Fabulous dead king. Don't hate me because I wo...  https://t.co/Aet5yhXkVA
# 1  Fabulous dead king. Don't hate me because I wo...  https://t.co/Aet5yhXkVA
# 2  Fabulous dead king. Don't hate me because I wo...  https://t.co/Aet5yhXkVA
#
#    protected  followers_count  friends_count  listed_count  statuses_count  \
# 0      False            10638            326            62           43773
# 1      False            10638            326            62           43773
# 2      False            10638            326            62           43773
#
#    favourites_count account_created_at  verified              profile_url  \
# 0             13547   2012-03-27 15:17     False  https://t.co/Aet5yhXkVA
# 1             13547   2012-03-27 15:17     False  https://t.co/Aet5yhXkVA
# 2             13547   2012-03-27 15:17     False  https://t.co/Aet5yhXkVA
#
#      profile_expanded_url account_lang  \
# 0  http://vissie4king.com          NaN
# 1  http://vissie4king.com          NaN
# 2  http://vissie4king.com          NaN
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/53823804...
# 1  https://pbs.twimg.com/profile_banners/53823804...
# 2  https://pbs.twimg.com/profile_banners/53823804...
#
#                              profile_background_url  \
# 0  http://abs.twimg.com/images/themes/theme4/bg.gif
# 1  http://abs.twimg.com/images/themes/theme4/bg.gif
# 2  http://abs.twimg.com/images/themes/theme4/bg.gif
#
#                                    profile_image_url
# 0  http://pbs.twimg.com/profile_images/7997334059...
# 1  http://pbs.twimg.com/profile_images/7997334059...
# 2  http://pbs.twimg.com/profile_images/7997334059...

# %% [markdown]
# # Tweet Length Distribution

# %%
tweets = pd.DataFrame(df['text'])

# %%
tweets['text'].apply(len).describe()
# Out:
# count    33532.000000
# mean       109.438596
# std         72.443352
# min          4.000000
# 25%         59.000000
# 50%         88.000000
# 75%        138.000000
# max       1914.000000
# Name: text, dtype: float64

# %%
text_lens = tweets['text'].apply(len).values
fig, ax = plt.subplots()
fig.set_size_inches(8, 5)
g = sns.distplot(text_lens, kde=False, bins=150, color='blue')
g.set_xlabel('Character length of tweets')
g.set_ylabel('Counts')
g.set_title('Tweet length distribution')
ax.set_xlim(1,450)
ax.grid(False)
plt.show()

# %% [markdown]
# # Wordcloud

# %%
# remove noise (links)
tweets['text'] = tweets['text'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])

# %%
# characters in tweets to replace
char_encoding = pd.read_csv('character conversion.csv')

# %%
emoji_encoding = pd.read_csv('emoji encoding.csv')

# %%
emoji_encoding.head(2)
# Out:
#   Char_conversion Description   Full Description Encoded Byte Twitter_data
# 0            ðŸŒ€     CYCLONE  CYCLONE <U+1F300>     0001f300    <U+1f300>
# 1            ðŸŒ       FOGGY    FOGGY <U+1F301>     0001f301    <U+1f301>

# %%
tweets['text'] = tweets['text'].str.replace('â','')
for i in range(len(char_encoding)):
    # replace emojis and certain characters with a better description
    tweets['text'] = tweets['text'].str.replace(char_encoding['char_conversion'][i],char_encoding['replace'][i])
    tweets['text'] = tweets['text'].str.replace(emoji_encoding['Char_conversion'][i],emoji_encoding['Description'][i])

# %%
# Collate the tweets into a larger one
tweets_concat = " ".join(tweet for tweet in tweets['text'])
stopwords = set(STOPWORDS)

# %%
# additional stopwords provided
stopwords2 = pd.read_csv('stopwords_gots8.csv',header=None)

# %%
stopwords |= set(stopwords2[0])

# %%
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
got_mask = np.array(Image.open(path.join(d, "got_throne.jpg")))

# %%
wc = WordCloud(background_color="white", max_words=500, mask=got_mask,
               stopwords=stopwords, contour_width=5.5, contour_color='black',
              margin=10)

# generate word cloud
wc.generate(tweets_concat)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Sentiment Analysis

# %%
sent_tweets = pd.DataFrame(df[['user_id','followers_count',
                               'text','created_at','source',
                              'screen_name']])

# %%
# Append the polarity scores
sid = SentimentIntensityAnalyzer()
sent_list = []
for index, row in tweets.iterrows():
    ss = sid.polarity_scores(row["text"])
    sent_list.append(ss)
sent_tweets['polarity'] = pd.Series(sent_list).values

# %%
sent_tweets = pd.concat([sent_tweets,sent_tweets.polarity.apply(pd.Series)],axis=1)

# %%
sent_tweets.sample(n=3)
# Out:
#            user_id  followers_count  \
# 26034  x1282434895             8922
# 3562   x2466814554              806
# 3957    x398694615              539
#
#                                                     text        created_at  \
# 26034                       @NiceQueenCersei Wild guess.  2019-04-16 15:25
# 3562   @kinda_cool @heathen_king Quite the opposite, ...  2019-05-06 14:41
# 3957   Less than an hour, folks. The realm us buzzing...   2019-05-20 0:11
#
#                    source   screen_name  \
# 26034  Twitter for iPhone  TheLadySansa
# 3562   Twitter for iPhone  ellariasnake
# 3957   Twitter for iPhone   FatPinkMast
#
#                                                 polarity    neg    neu    pos  \
# 26034  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 3562   {'neg': 0.119, 'neu': 0.703, 'pos': 0.177, 'co...  0.119  0.703  0.177
# 3957   {'neg': 0.138, 'neu': 0.724, 'pos': 0.138, 'co...  0.138  0.724  0.138
#
#        compound
# 26034    0.0000
# 3562     0.2263
# 3957     0.0000

# %% [markdown]
# # EDA I
# - Episode by episode sentiments (dates from IMDB)

# %%
def pseudo_date(df,date1,date2,ep_name):
    df.loc[(df['created_at']>=date1) &
           (df['created_at']<date2),'created_date_pseudo'] = '%s' %(ep_name)
    return df

# %%
sent_tweets['created_date_pseudo'] = 'Pre Episode 1'
sent_tweets = pseudo_date(sent_tweets,'2019-04-14','2019-04-21','S8 Episode 1')
sent_tweets = pseudo_date(sent_tweets,'2019-04-21','2019-04-28','S8 Episode 2')
sent_tweets = pseudo_date(sent_tweets,'2019-04-28','2019-05-05','S8 Episode 3')
sent_tweets = pseudo_date(sent_tweets,'2019-05-05','2019-05-12','S8 Episode 4')
sent_tweets = pseudo_date(sent_tweets,'2019-05-12','2019-05-19','S8 Episode 5')
sent_tweets = pseudo_date(sent_tweets,'2019-05-19','2019-05-26','S8 Episode 6')

# %%
sns.set_context("talk")
sns.set_style("white")
plt.figure(figsize=(10,7))
ax = sns.boxplot(x="created_date_pseudo", y="compound",data=sent_tweets)
ax.invert_xaxis()
ax.set(xlabel='', ylabel='Compound Sentiment Score',
       title='Sentiment Analysis')
locs, labels = plt.xticks()
plt.setp(labels, rotation=30)
sns.despine()
plt.show()

# %%
sent_tweets['Tweet Source'] = 'Other'
sent_tweets.loc[sent_tweets['source']=='Twitter for Android','Tweet Source'] = 'Android'
sent_tweets.loc[sent_tweets['source']=='Twitter for iPhone','Tweet Source'] = 'iPhone'
sent_tweets.loc[(sent_tweets['source']=='Twitter Web Client') |
           (sent_tweets['source']=='Twitter Web App'), 'Tweet Source'] = 'Web'

# %%
sns.set_context("talk")
sns.set_style("white")
plt.figure(figsize=(22,9))
ax = sns.boxplot(x="created_date_pseudo", y="compound",
                 hue='Tweet Source',data=sent_tweets)
ax.invert_xaxis()
ax.set(xlabel='', ylabel='Compound Sentiment Score',
       title='Sentiment Analysis')
locs, labels = plt.xticks()
plt.setp(labels, rotation=30)
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
sns.despine()
plt.show()

# %% [markdown]
# # Follower Count Influence

# %%
df_combine = pd.concat([df,sent_tweets.iloc[:,3:]],axis=1)

# %%
df_fci = df_combine[['user_id','favorite_count','favourites_count','followers_count','compound']]

# %%
infl = df_fci.groupby(['user_id']).agg({'followers_count':'mean',
                                        'compound':'mean'}).sort_values(by=['followers_count'],
                                                                                    ascending=False)

# %%
infl.reset_index(drop=True,inplace=True)

# %%
# going to bin follower counts, could use qcut but I dislike it.
infl['follower bin'] = '0 to 1000 followers'
infl.loc[(infl['followers_count']>1000)&
        (infl['followers_count']<10000),'follower_bin'] = '1000 to 10000 followers'
infl.loc[(infl['followers_count']>=10000)&
        (infl['followers_count']<50000),'follower_bin'] = '10000 to 50000 followers'
infl.loc[(infl['followers_count']>=50000),'follower_bin'] = '50000+ followers'

# %%
infl.rename(columns={'compound':'mean_compound'},inplace=True)

# %%
infl.sample(n=3)
# Out:
#     followers_count  mean_compound         follower bin  \
# 0     105966.463415       0.043888  0 to 1000 followers
# 5      33022.927618       0.039371  0 to 1000 followers
# 14      9365.302590       0.068395  0 to 1000 followers
#
#                 follower_bin
# 0           50000+ followers
# 5   10000 to 50000 followers
# 14   1000 to 10000 followers

# %%
infl_bins = infl.groupby(['follower_bin'])['mean_compound'].mean().reset_index().sort_values(by=['mean_compound'],
                                                                               ascending=False)

# %%
infl_bins
# Out:
#                follower_bin  mean_compound
# 0   1000 to 10000 followers       0.095439
# 1  10000 to 50000 followers       0.051117
# 2          50000+ followers       0.031432

# %%
sns.set_context("talk")
plt.figure(figsize=(10,6))
ax = sns.barplot(x="follower_bin", y="mean_compound", data=infl_bins,
                palette='Reds')
ax.set(xlabel='Binning By Followers', ylabel='Mean Compound Sentiment Score',
       title='Sentiment Analysis By Follower Binning')
plt.show()

# %% [markdown]
# # Per User Analysis

# %%
value1 = sent_tweets.groupby(['user_id','created_date_pseudo']).agg({'compound':'mean',
                                                           'text':'count'}).reset_index()

# %%
value1 = pd.merge(value1,sent_tweets[['user_id','followers_count','screen_name']].drop_duplicates(['user_id']))

# %%
value1 = value1.sort_values(by=['followers_count','user_id'],ascending=[False,True])

# %%
value1.rename(columns={'text':'number of tweets',
                      'compound':'mean compound score'},
             inplace=True)

# %%
value1.head(20)
# Out:
#         user_id created_date_pseudo  mean compound score  number of tweets  \
# 191  x710782219       Pre Episode 1             0.072372                39
# 192  x710782219        S8 Episode 1             0.123286                97
# 193  x710782219        S8 Episode 2             0.019573                92
# 194  x710782219        S8 Episode 3             0.099285               106
# 195  x710782219        S8 Episode 4             0.052493               121
# 196  x710782219        S8 Episode 5            -0.064342               161
# 197  x710782219        S8 Episode 6             0.092483                81
# 95   x304411861       Pre Episode 1            -0.205000                 6
# 96   x304411861        S8 Episode 1             0.047533                98
# 97   x304411861        S8 Episode 2             0.005923                43
# 98   x304411861        S8 Episode 3             0.032700                48
# 99   x304411861        S8 Episode 4            -0.003579               131
# 100  x304411861        S8 Episode 5             0.056928               199
# 101  x304411861        S8 Episode 6             0.044721               119
# 177  x607150882       Pre Episode 1             0.170706                67
# 178  x607150882        S8 Episode 1             0.123424               389
# 179  x607150882        S8 Episode 2             0.078348               296
# 180  x607150882        S8 Episode 3             0.054431               249
# 181  x607150882        S8 Episode 4             0.038476               206
# 182  x607150882        S8 Episode 5             0.146874               272
#
#      followers_count      screen_name
# 191           106845         Arya_No1
# 192           106845         Arya_No1
# 193           106845         Arya_No1
# 194           106845         Arya_No1
# 195           106845         Arya_No1
# 196           106845         Arya_No1
# 197           106845         Arya_No1
# 95            100557  Margaery_Tyrell
# 96            100557  Margaery_Tyrell
# 97            100557  Margaery_Tyrell
# 98            100557  Margaery_Tyrell
# 99            100557  Margaery_Tyrell
# 100           100557  Margaery_Tyrell
# 101           100557  Margaery_Tyrell
# 177            92320      danygonebad
# 178            92320      danygonebad
# 179            92320      danygonebad
# 180            92320      danygonebad
# 181            92320      danygonebad
# 182            92320      danygonebad
